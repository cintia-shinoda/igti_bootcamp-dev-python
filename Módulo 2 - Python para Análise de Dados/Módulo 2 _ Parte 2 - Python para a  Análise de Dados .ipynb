# %% [markdown]
# # Capítulo 4 - Introdução ao Aprendizado de Máquinas

# %% [markdown]
# ## 4.1 - Introdução ao Aprendizado de Máquinas

# %% [markdown]
# Arthur Samuel (1959): Machine Learning is the field of study that gives the computer the ability to learn without being explicitly programmed.

# %% [markdown]
# - O aprendizado de máquinas utiliza um conjunto de ferramentas para modelagem ee análise de dados denominado Aprendizado Estatístico
#
# - Abordagem estatística para o problema de Aprendizado de Máquina:
#     - desenvolvimento de modelos capazes de aprender a partir de dados

# %% [markdown]
# ### Abordagem simbólica
# - abordagem tradicional da programação
# - conhecimento  do problema é representado por meio de regras (if/else)
# - facilidade de entender o mecanismo de inferência que gerou o resultado
# - facilidade de alteração do conhecimento do problema

# %% [markdown]
# ## 4.2 - Introdução ao scikit-learn

# %% [markdown]
# ## 4.3 - Classificação: Conceitos Básicos

# %% [markdown]
# ## 4.4 - Classificação no scikit-learn II - Prática

# %% [markdown]
# ## 4.5 - Regressão Linear no scikit-learn I - Prática

# %% [markdown]
# ## 4.6 - Regressão Linear no scikit-learn II - Prática
