# %% [markdown]
# # Capítulo 4 - Introdução ao  Pygame

# %% [markdown]
# ## 4.1 - O que é Pygame?

# %%
# !pip install pygame
# Out:
# ...
#      |████████████████████████████████| 11.8 MB 4.6 MB/s
# ...
