# %% [markdown]
# # Capítulo 1 - Introdução ao Python

# %% [markdown]
# ## 1.1 - Introdução

# %% [markdown]
# ## 1.2 - Instalando o Python

# %% [markdown]
# ## 1.3 - Escolhendo a IDE

# %% [markdown]
# ## 1.4 - Primeiro contato com o Python

# %% [markdown]
# # Capítulo 2 - Escrevendo em Python

# %% [markdown]
# ## 2.1 - Sintax Python

# %% [markdown]
# ## 2.2 - Indentação

# %% [markdown]
# ## 2.3 - Variáveis

# %% [markdown]
# ## 2.4 - Comentários

# %% [markdown]
# ## 2.5 - Dicas de Boas Práticas em Python

# %% [markdown]
# # Capítulo 3 - Tipos de Dados em Python

# %% [markdown]
# ## 3.1 - Quais os Tipos de Dados em Python

# %% [markdown]
# ## 3.2 -  *String*

# %% [markdown]
# ## 3.3 - *Integer*

# %% [markdown]
# ## 3.4 - *Float*

# %% [markdown]
# ## 3.5 - Operações com os tipos em Python

# %% [markdown]
# # Capítulo 4 - List, Tuple, Sets e Dictionary

# %% [markdown]
# ## 4.1 - Formas de armazenar dados em Python

# %% [markdown]
# ## 4.2 - *List*

# %% [markdown]
# ## 4.3 - *Tuple*

# %% [markdown]
# ## 4.4 - *Sets*

# %% [markdown]
# ## 4.5 - *Dictionary*

# %% [markdown]
# https://github.com/erickfaria/fundamentos_em_python
