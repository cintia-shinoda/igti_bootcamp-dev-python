# %% [markdown]
# ## Objetivos

# %% [markdown]
# Exercitar os seguintes conceitos trabalhados no Módulo:
# - Sintax Python
# - Comentários em Python
# - Tipos de dados em Python
# - List, Tuple, Set e Dictionary

# %% [markdown]
# ## Enunciado

# %% [markdown]
# Prezado(a) estudante, chegou a hora de exercitarmos os conceitos aprendidos ao longo da primeira parte do Módulo 1 do Bootcamp de Desenvolvedor(a) Python.
# Para a realização desta atividade, você deve ter assistido os capítulos 1, 2, 3 e 4. Não se precipite e leia com
# atenção todas as questões.
#
# Lembre-se, o foco é aprender! Se for necessário retorne as aulas de conteúdo e assista novamente as aulas. Se houver dúvidas, pergunte no fórum.
#
# Para executar esta atividade, você deve observar os códigos a seguir e responder às questões correspondentes. Fique atento(a) aos espaços, indentações, e aos mínimos detalhes.
#
# Obs.¹: Não é necessário entregar nenhum código!
#
# Obs.²: Em caso de dúvida, não hesite em perguntar no fórum de dúvidas do trabalho
# prático.

# %% [markdown]
# ## Atividades

# %% [markdown]
# Os alunos deverão desempenhar as seguintes atividades:
# Em seu IDLE Python, copie e execute os seguintes códigos e responda as respectivas questões:

# %% [markdown]
# #  Q1
#
# A variável var_1 é um(a)?

# %%
var_1 = ['África do Sul', 'Namíbia', 'Congo']
type(var_1)
# Out:
# list

# %%
# Resposta: List

# %% [markdown]
# # Q2
#
# A variável var_2 é um(a)?

# %%
var_2 = (1, 2, 5, 4)
type(var_2)
# Out:
# tuple

# %%
# Resposta: Tuple

# %% [markdown]
# # Q3
#
# A variável var_3 é um(a)?

# %%
var_3 = {123, 456, 789, 1001}
type(var_3)
# Out:
# set

# %%
# Resposta: Set

# %% [markdown]
# # Q4
#
# A variável var_4 é um(a)?

# %%
var_4 = {'MG':'Minas Gerais',
 'SP':'São Paulo',
 'RJ':'Rio de Janeiro'}

type(var_4)
# Out:
# dict

# %%
# Resposta: Dictionary

# %% [markdown]
# # Q5
#
# Qual o tipo de dado que está armazenado na variável var_5?

# %%
var_5 = 5412
type(var_5)
# Out:
# int

# %%
# Resposta: Integer

# %% [markdown]
# # Q6
#
# Qual o tipo de dado que está armazenado na variável var_6?

# %%
var_6 = 45.4
type(var_6)
# Out:
# float

# %%
# Resposta: Float

# %% [markdown]
# # Q7
#
# Qual o tipo de dado que está armazenado na variável var_7?

# %%
var_7 = 'Curso de Desenvolvedor Python'
type(var_7)
# Out:
# str

# %%
# Resposta: String

# %% [markdown]
# # Q8
#
# Existe um erro na variável var_8? Se sim, qual?

# %%
var_8 = "Curso de Desenvolvedor Java

# %%
# Resposta: Sim. Falta uma aspas (") no fim do texto.

# %% [markdown]
# # Q9
#
# Na variável var_9 existe um sinal de #. O que ele significa?

# %%
var_9 = 10 + 10 # Soma

# %%
# Resposta: O sinal de # significa um comentário.

# %% [markdown]
# # Q10
#
# Existe um erro na variável var_10? Se sim, qual?

# %%
var_10 = print('Olá mundo)

# %%
# Resposta: Sim. Falta uma aspas simples no texto.

# %% [markdown]
# # Q11
#
# Qual o tipo de dado que está armazenado na variável var_11?

# %%
var_11 = '150'
type(var_11)
# Out:
# str

# %%
# Resposta: String

# %% [markdown]
# # Q12
#
# Existe um erro na variável var_12? Se sim, qual?

# %%
var_12 = ['House', 'The Office', "Friends"]

# %%
# Resposta: Não. A variável não apresenta erros.

# %% [markdown]
# # Q13
#
# Existe um erro na variável var_13? Se sim, qual?

# %%
var_13 = {55: 'Brasil'
 213: "Argelia"
 56: 'Chile'}

# %%
# Resposta: Sim. Faltam vírgulas para separar os valores.

# %% [markdown]
# # Q14
#
# Sobre a variável var_14, é CORRETO afirmar:

# %%
var_14 = 15 > 10
type(var_14)
# Out:
# bool

# %%
# Resposta: É uma variável do tipo boolean

# %% [markdown]
# # Q15
#
# Existe um erro na variável var_15? Se sim, qual?

# %%
var_15 <- 15

# %%
# Resposta: Sim. Em Python deve-se usar o sinal de = para declarar variáveis
